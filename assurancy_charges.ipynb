# %% [markdown]
# <a href="https://colab.research.google.com/github/gunelatakishyeva/MachineLearningProjects/blob/main/assurancy_charges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df['age'].value_counts()
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
X=df.drop('charges',axis=1)
y=df['charges'].copy()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#       age     sex     bmi  children smoker     region
# 1246   45  female  25.700         3     no  southwest
# 17     23    male  23.845         0     no  northeast
# 324    29    male  27.200         0     no  southwest
# 976    48    male  40.150         0     no  southeast
# 1328   23  female  24.225         2     no  northeast
# ...   ...     ...     ...       ...    ...        ...
# 1276   22  female  30.400         0     no  northeast
# 1120   23  female  31.400         0    yes  southwest
# 296    19    male  27.700         0    yes  southwest
# 32     19  female  28.600         5     no  southwest
# 67     40    male  26.315         1     no  northwest
#
# [1070 rows x 6 columns]

# %%
num_features=X_train.select_dtypes(include=[np.number]).columns
cat_features= X_train.select_dtypes(exclude=[np.number]).columns

# %%
num_features
# Out:
# Index(['age', 'bmi', 'children'], dtype='object')

# %%
cat_features
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
num_pipeline=Pipeline([
    ('impute',SimpleImputer(strategy='median'))
])
cat_pipeline=Pipeline([
    ('impute',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder())
])

transformer=ColumnTransformer([
    ('num_pipeline',num_pipeline,num_features),
    ('cat_pipeline',cat_pipeline,cat_features)
])

# %%
X_transformed_train=transformer.fit_transform(X_train)
transformed_columns=transformer.get_feature_names_out()
transformed_columns
# Out:
# array(['num_pipeline__age', 'num_pipeline__bmi', 'num_pipeline__children',
#        'cat_pipeline__sex_female', 'cat_pipeline__sex_male',
#        'cat_pipeline__smoker_no', 'cat_pipeline__smoker_yes',
#        'cat_pipeline__region_northeast', 'cat_pipeline__region_northwest',
#        'cat_pipeline__region_southeast', 'cat_pipeline__region_southwest'],
#       dtype=object)

# %%
X_transformed_train_df=pd.DataFrame(X_transformed_train,columns=transformed_columns)
X_transformed_train_df
# Out:
#       num_pipeline__age  num_pipeline__bmi  num_pipeline__children  \
# 0                  45.0             25.700                     3.0
# 1                  23.0             23.845                     0.0
# 2                  29.0             27.200                     0.0
# 3                  48.0             40.150                     0.0
# 4                  23.0             24.225                     2.0
# ...                 ...                ...                     ...
# 1065               22.0             30.400                     0.0
# 1066               23.0             31.400                     0.0
# 1067               19.0             27.700                     0.0
# 1068               19.0             28.600                     5.0
# 1069               40.0             26.315                     1.0
#
#       cat_pipeline__sex_female  cat_pipeline__sex_male  \
# 0                          1.0                     0.0
# ...

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X_transformed_train,y_train)
# Out:
# LinearRegression()

# %%
X_transformed_test=transformer.transform(X_test)
transformed_columns=transformer.get_feature_names_out()
transformed_columns
# Out:
# array(['num_pipeline__age', 'num_pipeline__bmi', 'num_pipeline__children',
#        'cat_pipeline__sex_female', 'cat_pipeline__sex_male',
#        'cat_pipeline__smoker_no', 'cat_pipeline__smoker_yes',
#        'cat_pipeline__region_northeast', 'cat_pipeline__region_northwest',
#        'cat_pipeline__region_southeast', 'cat_pipeline__region_southwest'],
#       dtype=object)

# %%
lin_reg.score(X_transformed_test,y_test)
# Out:
# 0.6450501807161346

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features=PolynomialFeatures(degree=2, include_bias=False)
X_poly=poly_features.fit_transform(X_transformed_train)

# %%
lin_reg=LinearRegression()
lin_reg.fit(X_poly,y_train)
lin_reg.intercept_,lin_reg.coef_
# Out:
# (-12839.95271672567,
#  array([-4.94468257e+01,  4.99278127e+02,  6.60744648e+02,  1.74995249e+02,
#         -1.74995249e+02,  3.82876110e+03, -3.82876110e+03,  2.89587458e+01,
#         -8.30576280e+01,  2.38629907e+02, -1.84531024e+02,  4.41035214e+00,
#          8.68986353e-01, -1.11352385e+00, -2.94966561e+01, -1.99501696e+01,
#         -2.53002313e+01, -2.41465945e+01, -4.85231583e+01, -1.99698704e+01,
#          1.68614100e+01,  2.18479297e+00, -6.64821321e+00, -1.16459543e+01,
#          2.40575123e+02,  2.58703004e+02, -4.87707194e+02,  9.86985321e+02,
#          1.88881734e+02,  1.27752769e+02,  5.45291036e+01,  1.28114520e+02,
#         -1.29428088e+02,  4.52287943e+02,  2.08456705e+02,  4.63610947e+02,
#          1.97133701e+02,  2.49469459e+02,  4.84911057e+02,  1.00712447e+02,
#         -1.74348315e+02,  1.74995249e+02,  0.00000000e+00,  2.16634403e+03,
#         -1.99134878e+03,  1.70703016e+02,  1.23324964e+02,  9.67967985e+01,
# ...

# %%
X_poly_test=poly_features.transform(X_transformed_test)

# %%
lin_reg.score(X_poly_test,y_test)
# Out:
# 0.7556732793022191

# %%
poly_features_10=PolynomialFeatures(degree=10, include_bias=False)
X_poly_10=poly_features_10.fit_transform(X_transformed_train)

# %%
lin_reg.fit(X_poly_10,y_train)
# Out:
# LinearRegression()

# %%
X_poly_test_10=poly_features_10.transform(X_transformed_test)

# %%
lin_reg.score(X_poly_10,y_train)
# Out:
# 0.9925659316719048
